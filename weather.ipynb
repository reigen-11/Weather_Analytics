# %% [markdown]
# ### WT03 - Thunder
# ### WT04 - Ice pellets, sleet, snow pellets, or small hail"
# ### PRCP - Precipitation
# ### WT05 - Hail (may include small hail)
# ### WT07 - Dust, volcanic ash, blowing dust, blowing sand, or blowing obstruction
# ### WT08 - Smoke or haze
# ### SNWD - Snow depth
# ### WT09 - Blowing or drifting snow
# ### WDF1 - Direction of fastest 1-minute wind
# ### WDF2 - Direction of fastest 2-minute wind
# ### WDF5 - Direction of fastest 5-second wind
# ### PGTM - Peak gust time
# ### TMAX - Maximum temperature
# ### FRGT - Top of frozen ground layer
# ### DAPR - Number of days included in the multiday precipitation total (MDPR)
# ### WSF2 - Fastest 2-minute wind speed
# ### FMTM - Time of fastest mile or fastest 1-minute wind
# ### ACMH - Average cloudiness midnight to midnight from manual observations
# ### WSF5 - Fastest 5-second wind speed
# ### SNOW - Snowfall
# ### WDFG - Direction of peak wind gust
# ### ACSH - Average cloudiness sunrise to sunset from manual observations
# ### WT16 - Rain (may include freezing rain, drizzle, and freezing drizzle)"
# ### WT18 - Snow, snow pellets, snow grains, or ice crystals
# ### WSF1 - Fastest 1-minute wind speed
# ### AWND - Average wind speed
# ### WSFG - Peak gust wind speed
# ### WT01 - Fog, ice fog, or freezing fog (may include heavy fog)
# ### WT02 - Heavy fog or heaving freezing fog (not always distinguished from fog)
# ### TAVG - Average Temperature.
# ### TMIN - Minimum temperature
# ### MDPR - Multiday precipitation total (use with DAPR and DWPR, if available)
# ### TSUN - Total sunshine for the period

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('climate.csv',parse_dates=['DATE'])
df
# Out:
#            STATION                                  NAME       DATE  ACMH  \
# 0      USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-02-28   NaN
# 1      USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-02-29   NaN
# 2      USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-03-01   NaN
# 3      USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-03-02   NaN
# 4      USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-03-03   NaN
# ...            ...                                   ...        ...   ...
# 21552  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 2023-02-01   NaN
# 21553  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 2023-02-02   NaN
# 21554  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 2023-02-03   NaN
# 21555  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 2023-02-04   NaN
# 21556  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 2023-02-05   NaN
#
#        ACSH   AWND  DAPR  FMTM  FRGT  MDPR  ...  WT01  WT02  WT03  WT04  WT05  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21557 entries, 0 to 21556
# Data columns (total 36 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  21557 non-null  object
#  1   NAME     21557 non-null  object
#  2   DATE     21557 non-null  datetime64[ns]
#  3   ACMH     5844 non-null   float64
#  4   ACSH     5844 non-null   float64
#  5   AWND     8425 non-null   float64
#  6   DAPR     8 non-null      float64
#  7   FMTM     2190 non-null   float64
#  8   FRGT     2 non-null      float64
#  9   MDPR     8 non-null      float64
#  10  PGTM     8516 non-null   float64
#  11  PRCP     21276 non-null  float64
#  12  SNOW     15705 non-null  float64
#  13  SNWD     15824 non-null  float64
#  14  TAVG     2037 non-null   float64
#  15  TMAX     21546 non-null  float64
#  16  TMIN     21543 non-null  float64
#  17  TSUN     1151 non-null   float64
#  18  WDF1     5844 non-null   float64
#  19  WDF2     8426 non-null   float64
# ...

# %% [markdown]
# ## Setting Dates as Index to easily access Index

# %%
df = df.set_index(df.DATE)

# %%
df
# Out:
#                 STATION                                  NAME       DATE  \
# DATE
# 1948-02-28  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-02-28
# 1948-02-29  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-02-29
# 1948-03-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-03-01
# 1948-03-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-03-02
# 1948-03-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-03-03
# ...                 ...                                   ...        ...
# 2023-02-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 2023-02-01
# 2023-02-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 2023-02-02
# 2023-02-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 2023-02-03
# 2023-02-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 2023-02-04
# 2023-02-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 2023-02-05
#
#             ACMH  ACSH   AWND  DAPR  FMTM  FRGT  MDPR  ...  WT01  WT02  WT03  \
# ...

# %%
df.loc['1948-02-28':'1965-1-31',:]
# Out:
#                 STATION                                  NAME       DATE  \
# DATE
# 1948-02-28  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-02-28
# 1948-02-29  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-02-29
# 1948-03-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-03-01
# 1948-03-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-03-02
# 1948-03-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1948-03-03
# ...                 ...                                   ...        ...
# 1965-01-27  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1965-01-27
# 1965-01-28  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1965-01-28
# 1965-01-29  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1965-01-29
# 1965-01-30  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1965-01-30
# 1965-01-31  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US 1965-01-31
#
#              ACMH   ACSH  AWND  DAPR  FMTM  FRGT  MDPR  ...  WT01  WT02  WT03  \
# ...

# %% [markdown]
# # DATA CLEANING

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# STATION     0.000000
# NAME        0.000000
# DATE        0.000000
# ACMH       72.890476
# ACSH       72.890476
# AWND       60.917567
# DAPR       99.962889
# FMTM       89.840887
# FRGT       99.990722
# MDPR       99.962889
# PGTM       60.495431
# PRCP        1.303521
# SNOW       27.146635
# SNWD       26.594610
# TAVG       90.550633
# TMAX        0.051028
# TMIN        0.064944
# TSUN       94.660667
# WDF1       72.890476
# WDF2       60.912929
# WDF5       61.321149
# WDFG       80.192049
# WSF1       72.890476
# WSF2       60.908290
# WSF5       61.321149
# WSFG       80.173494
# WT01       79.171499
# WT02       98.413508
# WT03       99.313448
# WT04       99.981445
# WT05       99.744862
# WT07       99.990722
# WT08       76.480957
# WT09       99.990722
# WT16       85.118523
# WT18       99.981445
# dtype: float64

# %%
core_weather = df[['PRCP','SNOW','SNWD','TMAX','TMIN']].copy()

# %%
core_weather.head(10)
# Out:
#             PRCP  SNOW  SNWD  TMAX  TMIN
# DATE
# 1948-02-28  0.08   0.0   NaN  56.0  40.0
# 1948-02-29  0.00   0.0   0.0  59.0  35.0
# 1948-03-01  0.00   0.0   0.0  59.0  41.0
# 1948-03-02  0.00   0.0   0.0  57.0  40.0
# 1948-03-03  0.00   0.0   0.0  60.0  35.0
# 1948-03-04  0.00   0.0   0.0  63.0  36.0
# 1948-03-05  0.00   0.0   0.0  55.0  35.0
# 1948-03-06  0.00   0.0   0.0  59.0  39.0
# 1948-03-07  0.00   0.0   0.0  62.0  39.0
# 1948-03-08  0.30   0.0   0.0  54.0  42.0

# %%
core_weather.columns = ['precip','snow','snow_depth','temp_max','temp_min']

# %%
core_weather.head()
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1948-02-28    0.08   0.0         NaN      56.0      40.0
# 1948-02-29    0.00   0.0         0.0      59.0      35.0
# 1948-03-01    0.00   0.0         0.0      59.0      41.0
# 1948-03-02    0.00   0.0         0.0      57.0      40.0
# 1948-03-03    0.00   0.0         0.0      60.0      35.0

# %%
(core_weather.isnull().sum()/core_weather.shape[0])*100
# Out:
# precip         1.303521
# snow          27.146635
# snow_depth    26.594610
# temp_max       0.051028
# temp_min       0.064944
# dtype: float64

# %%
core_weather.snow.value_counts()
# Out:
# 0.0    15704
# 1.0        1
# Name: snow, dtype: int64

# %%
del core_weather['snow']

# %%
core_weather.snow_depth.value_counts()
# Out:
# 0.0    15824
# Name: snow_depth, dtype: int64

# %%
del core_weather['snow_depth']

# %%
core_weather.precip.value_counts()
# Out:
# 0.00    17573
# 0.01      513
# 0.02      258
# 0.03      156
# 0.04      133
#         ...
# 1.21        1
# 1.34        1
# 1.62        1
# 2.06        1
# 5.01        1
# Name: precip, Length: 189, dtype: int64

# %%
core_weather.precip = core_weather.precip.fillna(0)

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip       0
# temp_max    11
# temp_min    14
# dtype: int64

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2004-11-20     0.0       NaN       NaN
# 2011-12-21     0.0      61.0       NaN
# 2011-12-22     0.0      62.0       NaN
# 2011-12-23     0.0      56.0       NaN
# 2011-12-24     0.0      55.0       NaN
# 2011-12-25     0.0      54.0       NaN
# 2013-06-16     0.0       NaN       NaN
# 2020-08-29     0.0       NaN       NaN
# 2020-09-08     0.0       NaN       NaN
# 2020-09-09     0.0       NaN       NaN
# 2022-10-08     0.0       NaN       NaN
# 2022-10-09     0.0       NaN       NaN
# 2022-10-10     0.0      69.0       NaN
# 2022-10-11     0.0      66.0       NaN

# %%
core_weather = core_weather.fillna(method="ffill")

# %%
core_weather.isnull().sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 21557 entries, 1948-02-28 to 2023-02-05
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   precip    21557 non-null  float64
#  1   temp_max  21557 non-null  float64
#  2   temp_min  21557 non-null  float64
# dtypes: float64(3)
# memory usage: 1.2 MB

# %% [markdown]
# #### 9's (e.g 9999)are the missing data in the dataset refer documentation

# %%
core_weather.apply(lambda x : (x == 9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %% [markdown]
# ## Analyzing Our Data

# %%
core_weather[['temp_max','temp_min']].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather.index.year.value_counts().unique()
# Out:
# array([366, 365, 308, 212, 184,  35])

# %%
core_weather.precip.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()
# Out:
#       precip  temp_max  temp_min
# DATE
# 1948   12.09   19968.0   14875.0
# 1949   14.98   23701.0   17355.0
# 1950   26.16   24148.0   17682.0
# 1951   22.20   23650.0   17734.0
# 1952   22.23   23842.0   17802.0
# ...      ...       ...       ...
# 2019   20.00   24896.0   18782.0
# 2020    6.42   25934.0   19021.0
# 2021   20.82   24506.0   18484.0
# 2022   15.38   24446.0   17901.0
# 2023    9.03    2034.0    1557.0
#
# [61 rows x 3 columns]

# %%
core_weather['target'] = core_weather.shift(-1)['temp_max']

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1948-02-28    0.08      56.0      40.0    59.0
# 1948-02-29    0.00      59.0      35.0    59.0
# 1948-03-01    0.00      59.0      41.0    57.0
# 1948-03-02    0.00      57.0      40.0    60.0
# 1948-03-03    0.00      60.0      35.0    63.0
# ...            ...       ...       ...     ...
# 2023-02-01    0.00      56.0      35.0    58.0
# 2023-02-02    0.00      58.0      37.0    57.0
# 2023-02-03    0.43      57.0      48.0    59.0
# 2023-02-04    0.20      59.0      49.0    56.0
# 2023-02-05    0.11      56.0      44.0     NaN
#
# [21557 rows x 4 columns]

# %%
core_weather = core_weather.iloc[:-1:,].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1948-02-28    0.08      56.0      40.0    59.0
# 1948-02-29    0.00      59.0      35.0    59.0
# 1948-03-01    0.00      59.0      41.0    57.0
# 1948-03-02    0.00      57.0      40.0    60.0
# 1948-03-03    0.00      60.0      35.0    63.0
# ...            ...       ...       ...     ...
# 2023-01-30    0.00      55.0      35.0    56.0
# 2023-02-01    0.00      56.0      35.0    58.0
# 2023-02-02    0.00      58.0      37.0    57.0
# 2023-02-03    0.43      57.0      48.0    59.0
# 2023-02-04    0.20      59.0      49.0    56.0
#
# [21556 rows x 4 columns]

# %% [markdown]
# ## ML Model

# %%
from sklearn.linear_model import Ridge

model = Ridge(alpha=0.1)

# %%
predictors = ['precip','temp_max','temp_min']

train = core_weather.loc[:'2020-12-31']
train
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1948-02-28    0.08      56.0      40.0    59.0
# 1948-02-29    0.00      59.0      35.0    59.0
# 1948-03-01    0.00      59.0      41.0    57.0
# 1948-03-02    0.00      57.0      40.0    60.0
# 1948-03-03    0.00      60.0      35.0    63.0
# ...            ...       ...       ...     ...
# 2020-12-27    0.00      63.0      44.0    61.0
# 2020-12-28    0.10      61.0      42.0    60.0
# 2020-12-29    0.00      60.0      39.0    56.0
# 2020-12-30    0.07      56.0      36.0    62.0
# 2020-12-31    0.06      62.0      44.0    60.0
#
# [20792 rows x 4 columns]

# %%
test = core_weather.loc['2021-01-01':]
test
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 2021-01-01    0.00      60.0      40.0    57.0
# 2021-01-02    0.14      57.0      51.0    56.0
# 2021-01-03    0.00      56.0      49.0    62.0
# 2021-01-04    0.36      62.0      46.0    59.0
# 2021-01-05    0.00      59.0      42.0    59.0
# ...            ...       ...       ...     ...
# 2023-01-30    0.00      55.0      35.0    56.0
# 2023-02-01    0.00      56.0      35.0    58.0
# 2023-02-02    0.00      58.0      37.0    57.0
# 2023-02-03    0.43      57.0      48.0    59.0
# 2023-02-04    0.20      59.0      49.0    56.0
#
# [764 rows x 4 columns]

# %%
model.fit(train[predictors],train['target'])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = model.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(test['target'],predictions)
# Out:
# 3.36326960976029

# %%
combined = pd.concat([test['target'],pd.Series(predictions,index=test.index)],axis=1)
combined.columns = ['actual','predicted']

# %%
combined
# Out:
#             actual  predicted
# DATE
# 2021-01-01    57.0  59.879365
# 2021-01-02    56.0  59.421110
# 2021-01-03    62.0  58.644950
# 2021-01-04    59.0  61.620914
# 2021-01-05    59.0  59.525294
# ...            ...        ...
# 2023-01-30    56.0  55.380928
# 2023-02-01    58.0  56.098744
# 2023-02-02    57.0  57.898118
# 2023-02-03    59.0  58.242880
# 2023-02-04    56.0  60.362112
#
# [764 rows x 2 columns]

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
plt.scatter(combined.index,combined.actual,c='blue',label = 'Actual')
plt.scatter(combined.index,combined.predicted,c='green',label = 'Predicted')

plt.legend()
plt.show()

# %%
def make_predictions(predictors,core_weather,model):
    train = core_weather.loc[:'2020-12-31']
    test = core_weather.loc['2021-01-01':]
    model.fit(train[predictors],train['target'])
    predictions = model.predict(test[predictors])
    error = mean_absolute_error(test['target'],predictions)
    combined = pd.concat([test['target'],pd.Series(predictions,index=test.index)],axis=1)
    combined.columns = ['actual','predicted']
    return error,combined

# %%
core_weather['month_max'] = core_weather['temp_max'].rolling(30).mean()

# %%
core_weather['max_min'] = core_weather.temp_max / core_weather.temp_min

# %%
core_weather['month_day_max'] = core_weather.month_max / core_weather.temp_max

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max   max_min  \
# DATE
# 1948-02-28    0.08      56.0      40.0    59.0        NaN  1.400000
# 1948-02-29    0.00      59.0      35.0    59.0        NaN  1.685714
# 1948-03-01    0.00      59.0      41.0    57.0        NaN  1.439024
# 1948-03-02    0.00      57.0      40.0    60.0        NaN  1.425000
# 1948-03-03    0.00      60.0      35.0    63.0        NaN  1.714286
# ...            ...       ...       ...     ...        ...       ...
# 2023-01-30    0.00      55.0      35.0    56.0  58.266667  1.571429
# 2023-02-01    0.00      56.0      35.0    58.0  58.066667  1.600000
# 2023-02-02    0.00      58.0      37.0    57.0  58.266667  1.567568
# 2023-02-03    0.43      57.0      48.0    59.0  58.333333  1.187500
# 2023-02-04    0.20      59.0      49.0    56.0  58.333333  1.204082
#
#             month_day_max
# DATE
# 1948-02-28            NaN
# 1948-02-29            NaN
# 1948-03-01            NaN
# 1948-03-02            NaN
# ...

# %%
missing_rows = core_weather[core_weather.isnull().any(axis=1)]

# %%
start = missing_rows.index[0]
end = missing_rows.index[-1]

# %%
end - start
# Out:
# Timedelta('28 days 00:00:00')

# %%
core_weather=core_weather.iloc[29:,:].copy()

# %%
predictors = ['precip','temp_max','temp_min','month_max','month_day_max','max_min']

error , combined = make_predictions(predictors,core_weather,model)

# %%
error
# Out:
# 3.310169210638068

# %%
combined
# Out:
#             actual  predicted
# DATE
# 2021-01-01    57.0  60.535051
# 2021-01-02    56.0  59.070114
# 2021-01-03    62.0  58.278470
# 2021-01-04    59.0  61.836969
# 2021-01-05    59.0  59.835518
# ...            ...        ...
# 2023-01-30    56.0  55.699619
# 2023-02-01    58.0  56.403617
# 2023-02-02    57.0  58.042693
# 2023-02-03    59.0  57.719065
# 2023-02-04    56.0  59.522586
#
# [764 rows x 2 columns]

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather['monthly_average'] = core_weather.temp_max.groupby(core_weather.index.month).apply(lambda x : x.expanding(1).mean())
# Out:
# /tmp/ipykernel_7238/170206538.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   core_weather['monthly_average'] = core_weather.temp_max.groupby(core_weather.index.month).apply(lambda x : x.expanding(1).mean())

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max   max_min  \
# DATE
# 1948-04-26    0.00      61.0      49.0    58.0  60.900000  1.244898
# 1948-04-27    0.00      58.0      50.0    50.0  60.900000  1.160000
# 1948-04-28    0.43      50.0      44.0    56.0  60.433333  1.136364
# 1948-04-29    0.59      56.0      40.0    61.0  60.333333  1.400000
# 1948-04-30    0.03      61.0      45.0    60.0  60.366667  1.355556
# ...            ...       ...       ...     ...        ...       ...
# 2023-01-30    0.00      55.0      35.0    56.0  58.266667  1.571429
# 2023-02-01    0.00      56.0      35.0    58.0  58.066667  1.600000
# 2023-02-02    0.00      58.0      37.0    57.0  58.266667  1.567568
# 2023-02-03    0.43      57.0      48.0    59.0  58.333333  1.187500
# 2023-02-04    0.20      59.0      49.0    56.0  58.333333  1.204082
#
#             month_day_max  monthly_average
# DATE
# 1948-04-26       0.998361        61.000000
# 1948-04-27       1.050000        59.500000
# ...

# %%
core_weather['avg_day_in_year'] = core_weather.temp_max.groupby(core_weather.index.day_of_year).apply(lambda x : x.expanding(1).mean())
# Out:
# /tmp/ipykernel_7238/3741471396.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   core_weather['avg_day_in_year'] = core_weather.temp_max.groupby(core_weather.index.day_of_year).apply(lambda x : x.expanding(1).mean())

# %%
predictors = ['precip','temp_max','temp_min','month_max','month_day_max','max_min','avg_day_in_year','monthly_average']

# %%
error , combined = make_predictions(predictors,core_weather,model)

# %%
error
# Out:
# 3.266956680055526

# %%
model.coef_
# Out:
# array([ -0.76775421,   0.40151365,   0.03153699,   0.32552294,
#        -16.20547693,   0.05163889,   0.07579359,   0.15480544])

# %%
combined['difference'] = (combined.actual - combined.predicted).abs()

# %%
combined.sort_values('difference',ascending=False)
# Out:
#             actual  predicted  difference
# DATE
# 2022-06-20    98.0  76.693874   21.306126
# 2022-05-23    86.0  69.829637   16.170363
# 2021-01-17    83.0  68.444999   14.555001
# 2022-09-03    91.0  76.667979   14.332021
# 2022-09-05   102.0  87.726674   14.273326
# ...            ...        ...         ...
# 2021-10-11    72.0  72.020394    0.020394
# 2022-07-04    74.0  73.984802    0.015198
# 2021-11-30    67.0  67.011706    0.011706
# 2021-08-06    74.0  74.006882    0.006882
# 2021-11-05    64.0  64.002879    0.002879
#
# [764 rows x 3 columns]
